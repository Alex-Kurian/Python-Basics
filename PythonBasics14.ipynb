# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-Kurian/Python-Basics/blob/main/PythonBasics14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
Supermarket=files.upload()
# Out:
#      <input type="file" id="files-ef62ab34-5e6b-4b0d-97c9-373167ef2f32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef62ab34-5e6b-4b0d-97c9-373167ef2f32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-556b577f-099d-4d74-adb7-88f036e0c4f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-556b577f-099d-4d74-adb7-88f036e0c4f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
Teamgoals={
    "Teams":['Argentina','Brazil'],
    'Goals':[5,3]
}
Teamgoaldf=pd.DataFrame(Teamgoals)
print(Teamgoaldf)
# Out:
#        Teams  Goals
# 0  Argentina      5
# 1     Brazil      3

# %%
import pandas as pd
Players={
    "Name":['Messi','Ronaldo','Neymar'],
    "Country":['Argentina','Portugal','Brazil']
}
Playersdf=pd.DataFrame(Players)
print(Playersdf)
# Out:
#       Name    Country
# 0    Messi  Argentina
# 1  Ronaldo   Portugal
# 2   Neymar     Brazil

# %%
import pandas as pd
C=['India','Japan','Spain']
Cap=['Delhi','Tokyo','Madrid']
Coudf=pd.DataFrame(Cap,C)
print(Coudf)
# Out:
#             0
# India   Delhi
# Japan   Tokyo
# Spain  Madrid

# %%
import pandas as pd
df=pd.read_csv('Supermarket_sales.csv')
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...
